# %%
#If not installed
#!pip install langchain-text-splitters

# %%
import langchain
import langchain_core
import langchain_text_splitters

print(langchain.__version__)
print(langchain_core.__version__)
# Out:
# 1.2.3
# 1.2.7

# %%
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter,SentenceTransformersTokenTextSplitter
)

# %%
#Character-based splitter
text = """Hopefully, you’ve seen the pattern that most
decision-making requires multiple data points and
types to make decisions. AI agents are replacing
manual data stitching with automated, accurate
insights — boosting productivity and enabling faster
strategic decisions that ultimately will help unlock
new revenue opportunities. Here is one thing to keep
in mind as you start the journey to give employees
a decision intelligence agent: delivering accurate
answers while ensuring data privacy becomes
increasingly complex as more data sources are
connected and more AI agents are built on top of
them. To address this from the start, it's important
to evaluate solutions with a platform mindset where
shared data governance, processing and retrieval
resources drive cost-efficiencies."""

# %%
splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=10,
    chunk_overlap=0,
)
chunks = splitter.split_text(text)
# Out:
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10

# %%
type(chunks)
# Out:
# list

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions
# 1 AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities
# 2 Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them
# 3 To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies

# %%
#Recursive splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=15,
    chunk_overlap=5,
)
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully,
# 1 you’ve seen
# 2 seen the
# 3 the pattern
# 4 that most
# 5 decision-makin
# 6 making
# 7 requires
# 8 multiple data
# 9 data points
# 10 and
# 11 types to make
# 12 decisions. AI
# 13 AI agents are
# 14 are replacing
# 15 manual data
# 16 data stitching
# 17 with
# 18 automated,
# 19 accurate
# 20 insights —
# 21 — boosting
# 22 productivity
# 23 and enabling
# 24 faster
# 25 strategic
# 26 decisions that
# 27 ultimately
# 28 will help
# 29 help unlock
# 30 new revenue
# 31 opportunities.
# 32 Here is one
# 33 one thing to
# 34 to keep
# 35 in mind as you
# 36 you start the
# 37 the journey to
# 38 to give
# 39 give employees
# 40 a decision
# 41 intelligence
# 42 agent:
# 43 delivering
# 19 accurate
# 45 answers while
# 46 ensuring data
# 47 data privacy
# 48 becomes
# 49 increasingly
# 50 complex as
# 51 as more data
# 52 data sources
# 53 are
# 54 connected and
# 55 and more AI
# 13 AI agents are
# 57 are built on
# 58 on top of
# 59 them. To
# 60 To address
# ...

# %%
#Recursive splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=7,
    chunk_overlap=0,
    separators=[" "]
)
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully,
# 1  you’ve
# 2 seen
# 3 the
# 4  pattern
# 5 that
# 6  most
# decision-making
# 7  requires
# 8  multiple
# 9 data
# 10  points
# 11  and
# types
# 12 to
# 13 make
# 14  decisions.
# 15 AI
# 16  agents
# 17 are
# 18  replacing
# manual
# 9 data
# 20  stitching
# 21 with
# 22  automated,
# 23  accurate
# insights
# 24 —
# 25  boosting
# 26  productivity
# 27 and
# 28  enabling
# 29  faster
# strategic
# 30  decisions
# 5 that
# 32  ultimately
# 33 will
# 34 help
# 35  unlock
# new
# 36  revenue
# 37  opportunities.
# 38 Here
# 39 is one
# 40 thing
# 12 to
# 42  keep
# in
# 43 mind
# 44 as you
# 45 start
# 3 the
# 47  journey
# 12 to
# 49 give
# 50  employees
# a
# 51  decision
# 52  intelligence
# 53  agent:
# 54  delivering
# 55  accurate
# answers
# 56 while
# 57  ensuring
# 9 data
# 59  privacy
# 60  becomes
# increasingly
# 61  complex
# 62 as
# 63 more
# 9 data
# 65  sources
# 66  are
# connected
# 27 and
# 63 more
# 15 AI
# 16  agents
# 17 are
# 72 built
# ...

# %%
splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=150,
    chunk_overlap=10,
)
chunks = splitter.split_text(text)
# Out:
# Created a chunk of size 203, which is longer than the specified 150
# Created a chunk of size 272, which is longer than the specified 150

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions
# 1 AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities
# 2 Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them
# 3 To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies

# %%
splitter = SentenceTransformersTokenTextSplitter(
    model_name="sentence-transformers/all-mpnet-base-v2",
    chunk_size=150,
    chunk_overlap=20,
)

# %%
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 hopefully, you ’ ve seen the pattern that most decision - making requires multiple data points and types to make decisions. ai agents are replacing manual data stitching with automated, accurate insights — boosting productivity and enabling faster strategic decisions that ultimately will help unlock new revenue opportunities. here is one thing to keep in mind as you start the journey to give employees a decision intelligence agent : delivering accurate answers while ensuring data privacy becomes increasingly complex as more data sources are connected and more ai agents are built on top of them. to address this from the start, it ' s important to evaluate solutions with a platform mindset where shared data governance, processing and retrieval resources drive cost - efficiencies.

# %%
#Token-aware splitter
splitter = TokenTextSplitter(chunk_size=100, chunk_overlap=10)
tokens = splitter.split_text(text)

# %%
for i in tokens:
  print(tokens.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions. AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities. Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly
# 1 wers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them. To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies.

# %%
from langchain_core.documents import Document

docs = [Document(page_content=text, metadata={})]
split_docs = splitter.split_documents(docs)

# %%
for i in split_docs:
  print(split_docs.index(i),i)
# Out:
# 0 page_content='Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions. AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities. Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly'
# 1 page_content='wers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them. To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies.'

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
model = "sentence-transformers/all-MiniLM-L6-v2"

# %%
embeddings = HuggingFaceEmbeddings(model_name=model)
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_9516\2590713520.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name=model)

# %%
text = "tell me something about langchain"

# %%
test_embedding = embeddings.embed_documents(text)

# %%
#print(test_embedding)
#type(test_embedding)
#len(test_embedding)

# %%
#check
for i in tokens:
  print(embeddings.embed_documents(i))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
